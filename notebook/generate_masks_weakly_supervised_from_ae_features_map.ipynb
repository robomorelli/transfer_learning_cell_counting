# %%
import torch
import numpy as np
from torchvision.transforms import transforms as T
import torch.nn as nn
import sys
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
sys.path.append('..')
sys.path.append('../dataset_loader')
sys.path.append('../model')
from config import *
from mpl_toolkits.axes_grid1 import make_axes_locatable
from skimage.feature import peak_local_max
from skimage.morphology import remove_small_holes, remove_small_objects, label
from skimage.segmentation import watershed
from scipy import ndimage


from dataset_loader.image_loader import *
from model.resunet import *
from utils import *

from torch.autograd import Variable
import matplotlib.pyplot as plt
import scipy.misc
from PIL import Image
import json
from scipy.signal import find_peaks
# %matplotlib inline

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

# %%
"../model_results/autoencoder/green/c-resunet_g_ae_test/"
# Out:
# '../model_results/autoencoder/green/c-resunet_g_ae_test/'

# %%
path = "../model_results/autoencoder/green/c-resunet_g_ae_test/"

# %%
for ix,m in enumerate(os.listdir(path)):
    print(ix,m)
# Out:
# 0 c-resunet_g_ae_test_0.h5

# %%
model_name = os.listdir(path)[0]#21
print(model_name)
# Out:
# c-resunet_g_ae_test_0.h5

# %%
try:
    c0=True

    model = nn.DataParallel(c_resunet(arch='c-ResUnet', n_features_start = 16, n_out = 3,c0=c0,
            pretrained = False, progress= True)).to(device)
    #model.load_state_dict(torch.load(path + '{}'.format(model_name))['model_state_dict'])
    model.load_state_dict(torch.load(path + '{}'.format(model_name)))
except:
    print('no c0 is used')
    c0=False

    model = nn.DataParallel(c_resunet(arch='c-ResUnet', n_features_start = 16, n_out = 3,c0=c0,
            pretrained = False, progress= True)).to(device)
    #model.load_state_dict(torch.load(path + '{}'.format(model_name))['model_state_dict'])
    model.load_state_dict(torch.load(path + '{}'.format(model_name)))
# Out:
# including c0 in the network
# Initializing conv2d weights with Kaiming He normal

# %%
test = False
dataset = 'green'

str(root).replace('notebook', '') + '/data/test/original_images/'

transform = T.Compose([T.Lambda(lambda x: x * 1. / 255),
                       T.ToTensor()
                       ])

cells_images = CellsLoader(Path(str(root).replace('notebook', '') + '/data/train_val/images/'),
                            Path(str(root).replace('notebook', '') + '/data/train_val/masks/'), 
                               val_split=0.3, transform = transform, test = test, exclude_RT=False)

filenames = cells_images.imgs_list

# %%
blocks = list(model.module.children()) #encoder, decoder, head

# %%
counter=0
# we will save the conv layer weights in this list
model_weights =[]
#we will save the 49 conv layers in this list
layers = []# get all the model children as list
for block in blocks:
    for n,p in list(block.named_modules()):
        if type(p) == nn.Conv2d:
            counter+=1
            model_weights.append(p.weight)
            layers.append(p)

# %%
conv_layers = []
remove = [5,8,11]
for i, l in enumerate(layers):
    if i not in remove:
        conv_layers.append(l)

# %% [markdown]
# ## c-resunet_g_ae_test take selected = 0
# ## with automatic selection we have selected = 9

# %%
 #selected = 9
selected_layer = 0

# %%
labels_df = pd.read_csv(str(labels_csv).replace('preprocessing', ''))
img_names = labels_df['img_name'].values
labels_df.set_index(['img_name'], inplace=True)

# %%
RADIUS = 20

# %%
feature_map.shape
# Out:
# torch.Size([1200, 1600])

# %%
# model inference
for ix, f in enumerate(filenames):
    img = cv2.imread(str(train_val_images) + '/' +f)
    img = transform(img)
    img = torch.unsqueeze(img, 0)
    img = img.to(device).float()

    with torch.no_grad():
        print("image {} num {} ".format(f, ix))
        outputs = []
        for layer in conv_layers:
            img = layer(img)
            outputs.append(img)
            
        #processed = []
        for feature_map in outputs[selected_layer]:
            
            feature_map = feature_map.squeeze(0)
            if len(feature_map.shape) < 3:
                print('here')
                gray_scale = feature_map
            else:
                gray_scale = torch.sum(feature_map,0)
                gray_scale = gray_scale / feature_map.shape[0]
            result = gray_scale.data.cpu().numpy()
            
    heat_map = (torch.from_numpy(result) - torch.from_numpy(result).min())\
                /(torch.from_numpy(result).max() - torch.from_numpy(result).min())
    med = torch.median(torch.flatten(heat_map))
    print(med)
    
    
    if med > 0.5:
        heat_map = 1 - heat_map
        med = torch.median(torch.flatten(heat_map))
        print(med)
        
    th = med + 0.5*med
    preds_t = (heat_map > th)

    # already circle images around dot annotation
    #mask = cv2.imread(str(train_val_masks) + '/' +f)
    #mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)[:, :, 0:1]
    
    mask = np.zeros((IMG_HEIGHT,IMG_WIDTH,3), np.uint8)
    mask.fill(0)
    print('\nGenerating mask for folder {}\n'.format(f))

    try:
        for index, r in labels_df.loc[f].iterrows():
            coords = r['dot']
            coords = [float(x.strip('(),')) for x in coords.split()]
            y, x = coords[0], coords[1]
            if 'RT' in f:
                cv2.circle(mask, (int(x), int(y)), RADIUS_RT, [255, 255, 255], -1)
            else:
                cv2.circle(mask, (int(x), int(y)), RADIUS, [255, 255, 255], -1)
    except:
        print('no coord for ',f)

    
    #mask_ws = create_mask(centers, f, radius=30, h=1200, w=1600)
    #mask_ws =  mask_ws.astype(bool)
    mask_ws = np.logical_and(np.squeeze(mask[:,:, 0]), preds_t)
    
    labels_pred, nlabels_pred = ndimage.label(mask_ws)
    processed = remove_small_holes(labels_pred, area_threshold=6, connectivity=1,
                                   in_place=False)
    processed = remove_small_objects(processed, min_size=60,
                                     connectivity=1, in_place=False)
    processed = processed.astype("uint8")*255

    torch.cuda.empty_cache()
    
    
    plt.imsave(os.path.join(str(train_val_ws_masks), f.split('.')[0]+'.png'),
               processed, cmap='gray')
# Out:
# image RT428S4C3R1_ParCort_100x_g.png num 0
# here
# tensor(0.1366)
#
# Generating mask for folder RT428S4C3R1_ParCort_100x_g.png
#
# image Mar26bS2C2R3_LHl_200x_g.png num 1
# here
# /home/roberto/anaconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:68: FutureWarning: in_place argument is deprecated and will be removed in version 1.0. To avoid this warning, please do not use the in_place argument. Please see remove_small_holes documentation for more details. Please use out argument instead.
# /home/roberto/anaconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:70: FutureWarning: in_place argument is deprecated and will be removed in version 1.0. To avoid this warning, please do not use the in_place argument. Please see remove_small_objects documentation for more details. Please use out argument instead.
# tensor(0.1354)
#
# Generating mask for folder Mar26bS2C2R3_LHl_200x_g.png
#
# image Mar24bS2C4R3_LHl_200x_g.png num 2
# here
# tensor(0.1444)
#
# Generating mask for folder Mar24bS2C4R3_LHl_200x_g.png
#
# image Mar19bS2C1R2_LHr_200x_g.png num 3
# here
# tensor(0.1610)
#
# Generating mask for folder Mar19bS2C1R2_LHr_200x_g.png
#
# image Mar21bS1C4R2_DMr_200x_g.png num 4
# here
# tensor(0.0910)
#
# Generating mask for folder Mar21bS1C4R2_DMr_200x_g.png
#
# image Mar24bS1C2R2_DMl_200x_g.png num 5
# here
# tensor(0.1398)
#
# Generating mask for folder Mar24bS1C2R2_DMl_200x_g.png
#
# image RT428S6C3R1_VLPAG_100x_g.png num 6
# here
# tensor(0.1002)
#
# Generating mask for folder RT428S6C3R1_VLPAG_100x_g.png
#
# image Mar26bS1C4R3_DMl_200x_g.png num 7
# here
# tensor(0.1394)
#
# Generating mask for folder Mar26bS1C4R3_DMl_200x_g.png
#
# image Mar20bS1C4R1_LHr_200x_g.png num 8
# here
# tensor(0.2477)
#
# Generating mask for folder Mar20bS1C4R1_LHr_200x_g.png
#
# image Mar20bS2C1R3_DMr_200x_g.png num 9
# here
# tensor(0.1575)
#
# Generating mask for folder Mar20bS2C1R3_DMr_200x_g.png
#
# image Mar19bS1C5R2_DMl_200x_g.png num 10
# here
# tensor(0.2639)
#
# Generating mask for folder Mar19bS1C5R2_DMl_200x_g.png
#
# image Mar24bS1C2R1_DMl_200x_g.png num 11
# here
# tensor(0.1191)
#
# Generating mask for folder Mar24bS1C2R1_DMl_200x_g.png
#
# image RT429S6C3R3_RVLM_100x_g.png num 12
# here
# tensor(0.2123)
#
# Generating mask for folder RT429S6C3R3_RVLM_100x_g.png
#
# image Mar26bS1C2R1_VLPAGr_200x_g.png num 13
# here
# tensor(0.1564)
#
# Generating mask for folder Mar26bS1C2R1_VLPAGr_200x_g.png
#
# image Mar21bS2C2R1_LHl_200x_g.png num 14
# here
# tensor(0.1342)
#
# Generating mask for folder Mar21bS2C2R1_LHl_200x_g.png
#
# image Mar23bS1C6R3_LHl_200x_g.png num 15
# here
# tensor(0.2382)
#
# Generating mask for folder Mar23bS1C6R3_LHl_200x_g.png
#
# image RT466S5C1R1_LH_100x_g.png num 16
# here
# tensor(0.1005)
#
# Generating mask for folder RT466S5C1R1_LH_100x_g.png
#
# image Mar24bS1C3R1_LHr_200x_g.png num 17
# here
# tensor(0.2004)
#
# Generating mask for folder Mar24bS1C3R1_LHr_200x_g.png
#
# image Mar20bS1C4R1_DMl_200x_g.png num 18
# here
# tensor(0.1684)
#
# Generating mask for folder Mar20bS1C4R1_DMl_200x_g.png
#
# image Mar21bS1C2R1_VLPAGr_200x_g.png num 19
# here
# tensor(0.1174)
#
# Generating mask for folder Mar21bS1C2R1_VLPAGr_200x_g.png
#
# image Mar20bS2C3R1_LHl_200x_g.png num 20
# here
# tensor(0.1522)
#
# Generating mask for folder Mar20bS2C3R1_LHl_200x_g.png
#
# image Mar23bS1C2R2_VLPAGl_200x_g.png num 21
# here
# tensor(0.1557)
#
# Generating mask for folder Mar23bS1C2R2_VLPAGl_200x_g.png
#
# image Mar23bS1C1R4_VLPAGr_200x_g.png num 22
# here
# tensor(0.1616)
#
# Generating mask for folder Mar23bS1C1R4_VLPAGr_200x_g.png
#
# image RT463S3C3R1_LH_100x_g.png num 23
# here
# tensor(0.1098)
#
# Generating mask for folder RT463S3C3R1_LH_100x_g.png
#
# image Mar19bS1C1R3_VLPAGr_200x_g.png num 24
# here
# tensor(0.1244)
#
# Generating mask for folder Mar19bS1C1R3_VLPAGr_200x_g.png
#
# no coord for  Mar19bS1C1R3_VLPAGr_200x_g.png
# image Mar26bS1C2R3_VLPAGl_200x_g.png num 25
# here
# tensor(0.1537)
#
# Generating mask for folder Mar26bS1C2R3_VLPAGl_200x_g.png
#
# image Mar22bS2C1R1_LHr_200x_g.png num 26
# here
# tensor(0.1685)
#
# Generating mask for folder Mar22bS2C1R1_LHr_200x_g.png
#
# image Mar24bS1C2R2_LHl_200x_g.png num 27
# here
# tensor(0.1064)
#
# Generating mask for folder Mar24bS1C2R2_LHl_200x_g.png
#
# image RT433S5C2R2_MM_100x_g.png num 28
# here
# tensor(0.1332)
#
# Generating mask for folder RT433S5C2R2_MM_100x_g.png
#
# image Mar27bS1C3R1_LHr_200x_g.png num 29
# here
# tensor(0.1306)
#
# Generating mask for folder Mar27bS1C3R1_LHr_200x_g.png
#
# image RT429S5C4R1_MM_100x_g.png num 30
# here
# tensor(0.1469)
#
# Generating mask for folder RT429S5C4R1_MM_100x_g.png
#
# image Mar23bS1C6R2_DMr_200x_g.png num 31
# here
# tensor(0.1950)
#
# Generating mask for folder Mar23bS1C6R2_DMr_200x_g.png
#
# image Mar19bS1C4R1_VLPAGr_200x_g.png num 32
# here
# tensor(0.2580)
#
# Generating mask for folder Mar19bS1C4R1_VLPAGr_200x_g.png
#
# image Mar24bS1C1R2_DMr_200x_g.png num 33
# here
# tensor(0.2120)
#
# Generating mask for folder Mar24bS1C1R2_DMr_200x_g.png
#
# image Mar24bS1C1R1_LHr_200x_g.png num 34
# here
# tensor(0.1095)
#
# Generating mask for folder Mar24bS1C1R1_LHr_200x_g.png
#
# image Mar26bS2C2R2_LHl_200x_g.png num 35
# here
# tensor(0.1269)
#
# Generating mask for folder Mar26bS2C2R2_LHl_200x_g.png
#
# image Mar22bS1C4R3_LHr_200x_g.png num 36
# here
# tensor(0.1660)
#
# Generating mask for folder Mar22bS1C4R3_LHr_200x_g.png
#
# image RT428S5C4R1_MM_100x_g.png num 37
# here
# tensor(0.1068)
#
# Generating mask for folder RT428S5C4R1_MM_100x_g.png
#
# image Mar20bS2C1R2_DMr_200x_g.png num 38
# here
# tensor(0.1713)
#
# Generating mask for folder Mar20bS2C1R2_DMr_200x_g.png
#
# image Mar19bS1C4R1_VLPAGl_200x_g.png num 39
# here
# tensor(0.1872)
#
# Generating mask for folder Mar19bS1C4R1_VLPAGl_200x_g.png
#
# image Mar23bS1C5R2_DMr_200x_g.png num 40
# here
# tensor(0.2046)
#
# Generating mask for folder Mar23bS1C5R2_DMr_200x_g.png
#
# image RT426S2C1R1_Septum_100x_g.png num 41
# here
# tensor(0.1668)
#
# Generating mask for folder RT426S2C1R1_Septum_100x_g.png
#
# image Mar21bS1C1R3_VLPAGr_200x_g.png num 42
# here
# tensor(0.1152)
#
# Generating mask for folder Mar21bS1C1R3_VLPAGr_200x_g.png
#
# image RT418S4C1R1_ParCort_100x_g.png num 43
# here
# tensor(0.1443)
#
# Generating mask for folder RT418S4C1R1_ParCort_100x_g.png
#
# image Mar19bS1C4R3_LHl_200x_g.png num 44
# here
# tensor(0.2035)
#
# Generating mask for folder Mar19bS1C4R3_LHl_200x_g.png
#
# image RT418S7C1R1_VLPAG_100x_g.png num 45
# here
# tensor(0.1120)
#
# Generating mask for folder RT418S7C1R1_VLPAG_100x_g.png
#
# image Mar20bS1C3R2_VLPAGr_200x_g.png num 46
# here
# tensor(0.1536)
#
# Generating mask for folder Mar20bS1C3R2_VLPAGr_200x_g.png
#
# image Mar23bS1C2R1_VLPAGl_200x_g.png num 47
# here
# tensor(0.1557)
#
# Generating mask for folder Mar23bS1C2R1_VLPAGl_200x_g.png
#
# image Mar20bS2C1R2_LHr_200x_g.png num 48
# here
# tensor(0.2194)
#
# Generating mask for folder Mar20bS2C1R2_LHr_200x_g.png
#
# image Mar26bS1C4R2_LHl_200x_g.png num 49
# here
# tensor(0.1075)
#
# Generating mask for folder Mar26bS1C4R2_LHl_200x_g.png
#
# image Mar26bS2C2R2_DMr_200x_g.png num 50
# here
# tensor(0.1405)
#
# Generating mask for folder Mar26bS2C2R2_DMr_200x_g.png
#
# image Mar19bS1C3R2_VLPAGl_200x_g.png num 51
# here
# tensor(0.1813)
#
# Generating mask for folder Mar19bS1C3R2_VLPAGl_200x_g.png
#
# image RT418S9C2R1_RVLM_100x_g.png num 52
# here
# tensor(0.1096)
#
# Generating mask for folder RT418S9C2R1_RVLM_100x_g.png
#
# image Mar23bS1C2R4_VLPAGr_200x_g.png num 53
# here
# tensor(0.1939)
#
# Generating mask for folder Mar23bS1C2R4_VLPAGr_200x_g.png
#
# image RT433S6C3R2_RVLM_100x_g.png num 54
# here
# tensor(0.1980)
#
# Generating mask for folder RT433S6C3R2_RVLM_100x_g.png
#
# image Mar22bS1C4R2_DMr_200x_g.png num 55
# here
# tensor(0.1322)
#
# Generating mask for folder Mar22bS1C4R2_DMr_200x_g.png
#
# image Mar24bS1C3R2_LHl_200x_g.png num 56
# here
# tensor(0.1967)
#
# Generating mask for folder Mar24bS1C3R2_LHl_200x_g.png
#
# image Mar26bS1C2R3_VLPAGr_200x_g.png num 57
# here
# tensor(0.1296)
#
# Generating mask for folder Mar26bS1C2R3_VLPAGr_200x_g.png
#
# image Mar26bS1C2R2_VLPAGr_200x_g.png num 58
# here
# tensor(0.1652)
#
# Generating mask for folder Mar26bS1C2R2_VLPAGr_200x_g.png
#
# image Mar19bS1C5R1_LHl_200x_g.png num 59
# here
# tensor(0.2425)
#
# Generating mask for folder Mar19bS1C5R1_LHl_200x_g.png
#
# image Mar23bS1C6R1_LHr_200x_g.png num 60
# here
# tensor(0.2647)
#
# Generating mask for folder Mar23bS1C6R1_LHr_200x_g.png
#
# image Mar26bS2C2R1_LHl_200x_g.png num 61
# here
# tensor(0.1310)
#
# Generating mask for folder Mar26bS2C2R1_LHl_200x_g.png
#
# image RT433S4C1R2_DM_100x_g.png num 62
# here
# tensor(0.2188)
#
# Generating mask for folder RT433S4C1R2_DM_100x_g.png
#
# image Mar19bS1C5R2_LHl_200x_g.png num 63
# here
# tensor(0.2776)
#
# Generating mask for folder Mar19bS1C5R2_LHl_200x_g.png
#
# image Mar24bS1C1R1_LHl_200x_g.png num 64
# here
# tensor(0.1277)
#
# Generating mask for folder Mar24bS1C1R1_LHl_200x_g.png
#
# image Mar21bS2C1R3_DMr_200x_g.png num 65
# here
# tensor(0.0974)
#
# Generating mask for folder Mar21bS2C1R3_DMr_200x_g.png
#
# image Mar19bS1C3R3_VLPAGr_200x_g.png num 66
# here
# tensor(0.1566)
#
# Generating mask for folder Mar19bS1C3R3_VLPAGr_200x_g.png
#
# image Mar19bS2C2R1_LHr_200x_g.png num 67
# here
# tensor(0.2174)
#
# Generating mask for folder Mar19bS2C2R1_LHr_200x_g.png
#
# image Mar20bS2C1R2_DMl_200x_g.png num 68
# here
# tensor(0.2259)
#
# Generating mask for folder Mar20bS2C1R2_DMl_200x_g.png
#
# image Mar22bS1C3R3_DMl_200x_g.png num 69
# here
# tensor(0.1564)
#
# Generating mask for folder Mar22bS1C3R3_DMl_200x_g.png
#
# image Mar20bS2C3R2_LHl_200x_g.png num 70
# here
# tensor(0.1468)
#
# Generating mask for folder Mar20bS2C3R2_LHl_200x_g.png
#
# image RT466S2C3R2_Septim_100x_g.png num 71
# here
# tensor(0.1088)
#
# Generating mask for folder RT466S2C3R2_Septim_100x_g.png
#
# image Mar20bS2C1R3_LHr_200x_g.png num 72
# here
# tensor(0.1375)
#
# Generating mask for folder Mar20bS2C1R3_LHr_200x_g.png
#
# image Mar21bS2C2R3_LHr_200x_g.png num 73
# here
# tensor(0.1517)
#
# Generating mask for folder Mar21bS2C2R3_LHr_200x_g.png
#
# image Mar26bS2C1R1_DMr_200x_g.png num 74
# here
# tensor(0.0964)
#
# Generating mask for folder Mar26bS2C1R1_DMr_200x_g.png
#
# image Mar20bS1C2R3_VLPAGr_200x_g.png num 75
# here
# tensor(0.2132)
#
# Generating mask for folder Mar20bS1C2R3_VLPAGr_200x_g.png
#
# image Mar22bS1C3R3_DMr_200x_g.png num 76
# here
# tensor(0.1409)
#
# Generating mask for folder Mar22bS1C3R3_DMr_200x_g.png
#
# image Mar21bS1C2R1_VLPAGl_200x_g.png num 77
# here
# tensor(0.1223)
#
# Generating mask for folder Mar21bS1C2R1_VLPAGl_200x_g.png
#
# image Mar26bS1C4R3_LHl_200x_g.png num 78
# here
# tensor(0.1283)
#
# Generating mask for folder Mar26bS1C4R3_LHl_200x_g.png
#
# image Mar23bS2C1R1_LHr_200x_g.png num 79
# here
# tensor(0.1360)
#
# Generating mask for folder Mar23bS2C1R1_LHr_200x_g.png
#
# image Mar21bS2C1R2_DMr_200x_g.png num 80
# here
# tensor(0.1171)
#
# Generating mask for folder Mar21bS2C1R2_DMr_200x_g.png
#
# image Mar22bS2C1R1_LHl_200x_g.png num 81
# here
# tensor(0.2270)
#
# Generating mask for folder Mar22bS2C1R1_LHl_200x_g.png
#
# image Mar22bS1C5R1_LHl_200x_g.png num 82
# here
# tensor(0.1758)
#
# Generating mask for folder Mar22bS1C5R1_LHl_200x_g.png
#
# image Mar21bS1C2R2_VLPAGl_200x_g.png num 83
# here
# tensor(0.1291)
#
# Generating mask for folder Mar21bS1C2R2_VLPAGl_200x_g.png
#
# image Mar21bS1C2R3_VLPAGr_200x_g.png num 84
# here
# tensor(0.1245)
#
# Generating mask for folder Mar21bS1C2R3_VLPAGr_200x_g.png
#
# image Mar22bS1C3R2_DMr_200x_g.png num 85
# here
# tensor(0.1418)
#
# Generating mask for folder Mar22bS1C3R2_DMr_200x_g.png
#
# image Mar20bS2C2R2_LHl_200x_g.png num 86
# here
# tensor(0.1739)
#
# Generating mask for folder Mar20bS2C2R2_LHl_200x_g.png
#
# image RT429S3C3R1_LH_100x_g.png num 87
# here
# tensor(0.1528)
#
# Generating mask for folder RT429S3C3R1_LH_100x_g.png
#
# image RT431S5C1R2_DM_100x_g.png num 88
# here
# tensor(0.1189)
#
# Generating mask for folder RT431S5C1R2_DM_100x_g.png
#
# image Mar26bS2C1R1_DMl_200x_g.png num 89
# here
# tensor(0.1106)
#
# Generating mask for folder Mar26bS2C1R1_DMl_200x_g.png
#
# image Mar19bS1C5R3_LHl_200x_g.png num 90
# here
# tensor(0.1799)
#
# Generating mask for folder Mar19bS1C5R3_LHl_200x_g.png
#
# image Mar20bS1C2R2_VLPAGr_200x_g.png num 91
# here
# tensor(0.1548)
#
# Generating mask for folder Mar20bS1C2R2_VLPAGr_200x_g.png
#
# image Mar20bS2C1R1_DMl_200x_g.png num 92
# here
# tensor(0.1877)
#
# Generating mask for folder Mar20bS2C1R1_DMl_200x_g.png
#
# image Mar22bS1C4R1_LHr_200x_g.png num 93
# here
# tensor(0.1874)
#
# Generating mask for folder Mar22bS1C4R1_LHr_200x_g.png
#
# image RT426S5C1R1_MM_100x_g.png num 94
# here
# tensor(0.1377)
#
# Generating mask for folder RT426S5C1R1_MM_100x_g.png
#
# image Mar26bS1C4R2_DMl_200x_g.png num 95
# here
# tensor(0.1129)
#
# Generating mask for folder Mar26bS1C4R2_DMl_200x_g.png
#
# image Mar24bS2C4R3_LHr_200x_g.png num 96
# here
# tensor(0.1809)
#
# Generating mask for folder Mar24bS2C4R3_LHr_200x_g.png
#
# image Mar20bS2C2R1_LHr_200x_g.png num 97
# here
# tensor(0.2568)
#
# Generating mask for folder Mar20bS2C2R1_LHr_200x_g.png
#
# image RT426S4C1R1_ParCort_100x_g.png num 98
# here
# tensor(0.1177)
#
# Generating mask for folder RT426S4C1R1_ParCort_100x_g.png
#
# image RT426S6C2R2_RVLM_100x_g.png num 99
# here
# tensor(0.1229)
#
# Generating mask for folder RT426S6C2R2_RVLM_100x_g.png
#
# image RT429S4C3R3_VLPAG_100x_g.png num 100
# here
# tensor(0.1340)
#
# Generating mask for folder RT429S4C3R3_VLPAG_100x_g.png
#
# image Mar20bS1C1R3_VLPAGl_200x_g.png num 101
# here
# tensor(0.2312)
#
# Generating mask for folder Mar20bS1C1R3_VLPAGl_200x_g.png
#
# image Mar26bS2C2R2_LHr_200x_g.png num 102
# here
# tensor(0.1205)
#
# Generating mask for folder Mar26bS2C2R2_LHr_200x_g.png
#
# image Mar24bS1C2R2_LHr_200x_g.png num 103
# here
# tensor(0.1318)
#
# Generating mask for folder Mar24bS1C2R2_LHr_200x_g.png
#
# image Mar21bS2C1R3_LHr_200x_g.png num 104
# here
# tensor(0.0976)
#
# Generating mask for folder Mar21bS2C1R3_LHr_200x_g.png
#
# image Mar23bS1C6R1_DMr_200x_g.png num 105
# here
# tensor(0.2694)
#
# Generating mask for folder Mar23bS1C6R1_DMr_200x_g.png
#
# image Mar19bS2C1R1_LHr_200x_g.png num 106
# here
# tensor(0.1519)
#
# Generating mask for folder Mar19bS2C1R1_LHr_200x_g.png
#
# image Mar24bS2C2R3_VLPAGr_200x_g.png num 107
# here
# tensor(0.1613)
#
# Generating mask for folder Mar24bS2C2R3_VLPAGr_200x_g.png
#
# image Mar20bS2C3R1_LHr_200x_g.png num 108
# here
# tensor(0.2529)
#
# Generating mask for folder Mar20bS2C3R1_LHr_200x_g.png
#
# image Mar21bS2C1R1_LHl_200x_g.png num 109
# here
# tensor(0.0901)
#
# Generating mask for folder Mar21bS2C1R1_LHl_200x_g.png
#
# image Mar23bS1C5R3_LHl_200x_g.png num 110
# here
# tensor(0.2121)
#
# Generating mask for folder Mar23bS1C5R3_LHl_200x_g.png
#
# image Mar22bS1C4R2_DMl_200x_g.png num 111
# here
# tensor(0.1339)
#
# Generating mask for folder Mar22bS1C4R2_DMl_200x_g.png
#
# image RT428S5C1R1_DM_100x_g.png num 112
# here
# tensor(0.1154)
#
# Generating mask for folder RT428S5C1R1_DM_100x_g.png
#
# image Mar26bS2C3R1_LHr_200x_g.png num 113
# here
# tensor(0.1218)
#
# Generating mask for folder Mar26bS2C3R1_LHr_200x_g.png
#
# image Mar21bS2C2R2_DMl_200x_g.png num 114
# here
# tensor(0.1290)
#
# Generating mask for folder Mar21bS2C2R2_DMl_200x_g.png
#
# image Mar22bS1C4R2_LHl_200x_g.png num 115
# here
# tensor(0.1427)
#
# Generating mask for folder Mar22bS1C4R2_LHl_200x_g.png
#
# image Mar23bS1C5R3_LHr_200x_g.png num 116
# here
# tensor(0.1437)
#
# Generating mask for folder Mar23bS1C5R3_LHr_200x_g.png
#
# image Mar20bS2C1R2_LHl_200x_g.png num 117
# here
# tensor(0.2385)
#
# Generating mask for folder Mar20bS2C1R2_LHl_200x_g.png
#
# image Mar20bS2C2R3_LHr_200x_g.png num 118
# here
# tensor(0.1759)
#
# Generating mask for folder Mar20bS2C2R3_LHr_200x_g.png
#
# image Mar23bS1C5R2_LHl_200x_g.png num 119
# here
# tensor(0.1300)
#
# Generating mask for folder Mar23bS1C5R2_LHl_200x_g.png
#
# image Mar26bS2C1R2_LHr_200x_g.png num 120
# here
# tensor(0.1237)
#
# Generating mask for folder Mar26bS2C1R2_LHr_200x_g.png
#
# image Mar19bS2C1R1_LHl_200x_g.png num 121
# here
# tensor(0.1400)
#
# Generating mask for folder Mar19bS2C1R1_LHl_200x_g.png
#
# image RT466S5C1R1_DM_100x_g.png num 122
# here
# tensor(0.1088)
#
# Generating mask for folder RT466S5C1R1_DM_100x_g.png
#
# image Mar19bS1C5R3_DMr_200x_g.png num 123
# here
# tensor(0.1799)
#
# Generating mask for folder Mar19bS1C5R3_DMr_200x_g.png
#
# image RT466S6C3R1_MM_100x_g.png num 124
# here
# tensor(0.1019)
#
# Generating mask for folder RT466S6C3R1_MM_100x_g.png
#
# image Mar26bS2C1R1_LHr_200x_g.png num 125
# here
# tensor(0.0961)
#
# Generating mask for folder Mar26bS2C1R1_LHr_200x_g.png
#
# image Mar27bS1C3R1_LHl_200x_g.png num 126
# here
# tensor(0.1276)
#
# Generating mask for folder Mar27bS1C3R1_LHl_200x_g.png
#
# image RT418S4C3R1_DM_100x_g.png num 127
# here
# tensor(0.1273)
#
# Generating mask for folder RT418S4C3R1_DM_100x_g.png
#
# image Mar24bS2C4R3_DMl_200x_g.png num 128
# here
# tensor(0.2170)
#
# Generating mask for folder Mar24bS2C4R3_DMl_200x_g.png
#
# image Mar20bS1C3R2_VLPAGl_200x_g.png num 129
# here
# tensor(0.2726)
#
# Generating mask for folder Mar20bS1C3R2_VLPAGl_200x_g.png
#
# image Mar19bS1C1R3_VLPAGl_200x_g.png num 130
# here
# tensor(0.2732)
#
# Generating mask for folder Mar19bS1C1R3_VLPAGl_200x_g.png
#
# image Mar24bS1C2R3_LHl_200x_g.png num 131
# here
# tensor(0.1361)
#
# Generating mask for folder Mar24bS1C2R3_LHl_200x_g.png
#
# image Mar23bS2C1R1_LHl_200x_g.png num 132
# here
# tensor(0.1875)
#
# Generating mask for folder Mar23bS2C1R1_LHl_200x_g.png
#
# image Mar24bS1C2R2_DMr_200x_g.png num 133
# here
# tensor(0.1264)
#
# Generating mask for folder Mar24bS1C2R2_DMr_200x_g.png
#
# image Mar23bS1C6R2_LHl_200x_g.png num 134
# here
# tensor(0.1318)
#
# Generating mask for folder Mar23bS1C6R2_LHl_200x_g.png
#
# image RT463S6C2R1_RVLM_100x_g.png num 135
# here
# tensor(0.1497)
#
# Generating mask for folder RT463S6C2R1_RVLM_100x_g.png
#
# image Mar26bS2C1R2_DMr_200x_g.png num 136
# here
# tensor(0.1097)
#
# Generating mask for folder Mar26bS2C1R2_DMr_200x_g.png
#
# image Mar26bS1C1R4_VLPAGr_200x_g.png num 137
# here
# tensor(0.1796)
#
# Generating mask for folder Mar26bS1C1R4_VLPAGr_200x_g.png
#
# image Mar21bS1C2R3_VLPAGl_200x_g.png num 138
# here
# tensor(0.1603)
#
# Generating mask for folder Mar21bS1C2R3_VLPAGl_200x_g.png
#
# image Mar19bS1C5R1_LHr_200x_g.png num 139
# here
# tensor(0.3248)
#
# Generating mask for folder Mar19bS1C5R1_LHr_200x_g.png
#
# image Mar20bS1C4R3_DMr_200x_g.png num 140
# here
# tensor(0.2040)
#
# Generating mask for folder Mar20bS1C4R3_DMr_200x_g.png
#
# image RT426S4C2R2_DM_100x_g.png num 141
# here
# tensor(0.1146)
#
# Generating mask for folder RT426S4C2R2_DM_100x_g.png
#
# image Mar26bS1C1R4_VLPAGl_200x_g.png num 142
# here
# tensor(0.1450)
#
# Generating mask for folder Mar26bS1C1R4_VLPAGl_200x_g.png
#
# image Mar21bS1C4R2_DMl_200x_g.png num 143
# here
# tensor(0.0948)
#
# Generating mask for folder Mar21bS1C4R2_DMl_200x_g.png
#
# image Mar19bS1C4R2_LHl_200x_g.png num 144
# here
# tensor(0.1855)
#
# Generating mask for folder Mar19bS1C4R2_LHl_200x_g.png
#
# image Mar20bS1C2R1_VLPAGl_200x_g.png num 145
# here
# tensor(0.2008)
#
# Generating mask for folder Mar20bS1C2R1_VLPAGl_200x_g.png
#
# image RT466S11C2R2_RVLM_100x_g.png num 146
# here
# tensor(0.1023)
#
# Generating mask for folder RT466S11C2R2_RVLM_100x_g.png
#
# image Mar26bS2C1R2_LHl_200x_g.png num 147
# here
# tensor(0.1277)
#
# Generating mask for folder Mar26bS2C1R2_LHl_200x_g.png
#
# image Mar21bS2C3R2_LHr_200x_g.png num 148
# here
# tensor(0.1055)
#
# Generating mask for folder Mar21bS2C3R2_LHr_200x_g.png
#
# image RT431S9C3R1_RVLM_100x_g.png num 149
# here
# tensor(0.1178)
#
# Generating mask for folder RT431S9C3R1_RVLM_100x_g.png
#
# no coord for  RT431S9C3R1_RVLM_100x_g.png
# image Mar22bS1C4R2_LHr_200x_g.png num 150
# here
# tensor(0.1213)
#
# Generating mask for folder Mar22bS1C4R2_LHr_200x_g.png
#
# image RT426S5C3R3_VLPAG_100x_g.png num 151
# here
# tensor(0.0986)
#
# Generating mask for folder RT426S5C3R3_VLPAG_100x_g.png
#
# image Mar19bS1C2R2_VLPAGr_200x_g.png num 152
# here
# tensor(0.1607)
#
# Generating mask for folder Mar19bS1C2R2_VLPAGr_200x_g.png
#
# image Mar26bS2C3R1_LHl_200x_g.png num 153
# here
# tensor(0.1100)
#
# Generating mask for folder Mar26bS2C3R1_LHl_200x_g.png
#
# image RT428S7C2R2_RVLM_100x_g.png num 154
# here
# tensor(0.1181)
#
# Generating mask for folder RT428S7C2R2_RVLM_100x_g.png
#
# image Mar21bS2C2R1_LHr_200x_g.png num 155
# here
# tensor(0.1164)
#
# Generating mask for folder Mar21bS2C2R1_LHr_200x_g.png
#
# image Mar20bS1C2R3_VLPAGl_200x_g.png num 156
# here
# tensor(0.2299)
#
# Generating mask for folder Mar20bS1C2R3_VLPAGl_200x_g.png
#
# image Mar20bS2C2R3_LHl_200x_g.png num 157
# here
# tensor(0.1548)
#
# Generating mask for folder Mar20bS2C2R3_LHl_200x_g.png
#
# image Mar26bS2C2R1_LHr_200x_g.png num 158
# here
# tensor(0.1853)
#
# Generating mask for folder Mar26bS2C2R1_LHr_200x_g.png
#
# image Mar26bS2C2R2_DMl_200x_g.png num 159
# here
# tensor(0.1379)
#
# Generating mask for folder Mar26bS2C2R2_DMl_200x_g.png
#
# image Mar26bS2C2R1_DMl_200x_g.png num 160
# here
# tensor(0.1300)
#
# Generating mask for folder Mar26bS2C2R1_DMl_200x_g.png
#
# image Mar24bS2C2R2_VLPAGr_200x_g.png num 161
# here
# tensor(0.1989)
#
# Generating mask for folder Mar24bS2C2R2_VLPAGr_200x_g.png
#
# image RT433S5C4R2_VLPAG_100x_g.png num 162
# here
# tensor(0.1641)
#
# Generating mask for folder RT433S5C4R2_VLPAG_100x_g.png
#
# image Mar20bS2C2R2_DMr_200x_g.png num 163
# here
# tensor(0.1667)
#
# Generating mask for folder Mar20bS2C2R2_DMr_200x_g.png
#
# image Mar19bS2C1R1_DMr_200x_g.png num 164
# here
# tensor(0.1669)
#
# Generating mask for folder Mar19bS2C1R1_DMr_200x_g.png
#
# image Mar22bS1C3R2_DMl_200x_g.png num 165
# here
# tensor(0.1416)
#
# Generating mask for folder Mar22bS1C3R2_DMl_200x_g.png
#
# image Mar23bS1C1R4_VLPAGl_200x_g.png num 166
# here
# tensor(0.2478)
#
# Generating mask for folder Mar23bS1C1R4_VLPAGl_200x_g.png
#
# image Mar19bS1C3R3_VLPAGl_200x_g.png num 167
# here
# tensor(0.1809)
#
# Generating mask for folder Mar19bS1C3R3_VLPAGl_200x_g.png
#
# image RT431S6C2R2_MM_100x_g.png num 168
# here
# tensor(0.1180)
#
# Generating mask for folder RT431S6C2R2_MM_100x_g.png
#
# image Mar20bS1C4R3_LHr_200x_g.png num 169
# here
# tensor(0.1702)
#
# Generating mask for folder Mar20bS1C4R3_LHr_200x_g.png
#
# image Mar21bS2C2R2_LHr_200x_g.png num 170
# here
# tensor(0.1298)
#
# Generating mask for folder Mar21bS2C2R2_LHr_200x_g.png
#
# image Mar21bS2C1R3_LHl_200x_g.png num 171
# here
# tensor(0.0978)
#
# Generating mask for folder Mar21bS2C1R3_LHl_200x_g.png
#
# image RT429S2C2R1_Sept_100x_g.png num 172
# here
# tensor(0.2030)
#
# Generating mask for folder RT429S2C2R1_Sept_100x_g.png
#
# image Mar26bS1C4R2_DMr_200x_g.png num 173
# here
# tensor(0.1071)
#
# Generating mask for folder Mar26bS1C4R2_DMr_200x_g.png
#
# image Mar26bS2C1R1_LHl_200x_g.png num 174
# here
# tensor(0.1602)
#
# Generating mask for folder Mar26bS2C1R1_LHl_200x_g.png
#
# image RT433S4C1R2_LH_100x_g.png num 175
# here
# tensor(0.1712)
#
# Generating mask for folder RT433S4C1R2_LH_100x_g.png
#
# image Mar22bS1C1R3_VLPAGr_200x_g.png num 176
# here
# tensor(0.1441)
#
# Generating mask for folder Mar22bS1C1R3_VLPAGr_200x_g.png
#
# image RT426S4C2R2_LH_100x_g.png num 177
# here
# tensor(0.1119)
#
# Generating mask for folder RT426S4C2R2_LH_100x_g.png
#
# image Mar20bS2C3R2_LHr_200x_g.png num 178
# here
# tensor(0.2387)
#
# Generating mask for folder Mar20bS2C3R2_LHr_200x_g.png
#
# image Mar20bS1C4R1_DMr_200x_g.png num 179
# here
# tensor(0.1661)
#
# Generating mask for folder Mar20bS1C4R1_DMr_200x_g.png
#
# image RT463S3C2R1_ParCortex_100x_g.png num 180
# here
# tensor(0.1252)
#
# Generating mask for folder RT463S3C2R1_ParCortex_100x_g.png
#
# image Mar24bS1C1R2_DMl_200x_g.png num 181
# here
# tensor(0.1189)
#
# Generating mask for folder Mar24bS1C1R2_DMl_200x_g.png
#
# image Mar22bS1C2R4_DMl_200x_g.png num 182
# here
# tensor(0.1825)
#
# Generating mask for folder Mar22bS1C2R4_DMl_200x_g.png
#
# image Mar19bS1C5R3_DMl_200x_g.png num 183
# here
# tensor(0.2143)
#
# Generating mask for folder Mar19bS1C5R3_DMl_200x_g.png
#
# image RT431S2C2R1_Septum_100x_g.png num 184
# here
# tensor(0.0985)
#
# Generating mask for folder RT431S2C2R1_Septum_100x_g.png
#
# image Mar22bS1C5R1_LHr_200x_g.png num 185
# here
# tensor(0.1892)
#
# Generating mask for folder Mar22bS1C5R1_LHr_200x_g.png
#
# image Mar19bS1C1R2_VLPAGr_200x_g.png num 186
# here
# tensor(0.1513)
#
# Generating mask for folder Mar19bS1C1R2_VLPAGr_200x_g.png
#
# image Mar21bS2C3R2_LHl_200x_g.png num 187
# here
# tensor(0.0973)
#
# Generating mask for folder Mar21bS2C3R2_LHl_200x_g.png
#
# image Mar19bS1C3R1_VLPAGl_200x_g.png num 188
# here
# tensor(0.2151)
#
# Generating mask for folder Mar19bS1C3R1_VLPAGl_200x_g.png
#
# image Mar23bS1C6R1_LHl_200x_g.png num 189
# here
# tensor(0.1716)
#
# Generating mask for folder Mar23bS1C6R1_LHl_200x_g.png
#
# image Mar19bS1C3R2_VLPAGr_200x_g.png num 190
# here
# tensor(0.1661)
#
# Generating mask for folder Mar19bS1C3R2_VLPAGr_200x_g.png
#
# image Mar20bS1C3R1_VLPAGr_200x_g.png num 191
# here
# tensor(0.2166)
#
# Generating mask for folder Mar20bS1C3R1_VLPAGr_200x_g.png
#
# image Mar19bS2C1R1_DMl_200x_g.png num 192
# here
# tensor(0.1595)
#
# Generating mask for folder Mar19bS2C1R1_DMl_200x_g.png
#
# image RT433S2C2R1_Septum_100x_g.png num 193
# here
# tensor(0.2327)
#
# Generating mask for folder RT433S2C2R1_Septum_100x_g.png
#
# image Mar24bS1C2R1_LHr_200x_g.png num 194
# here
# tensor(0.1298)
#
# Generating mask for folder Mar24bS1C2R1_LHr_200x_g.png
#
# image Mar22bS1C4R3_DMl_200x_g.png num 195
# here
# tensor(0.1985)
#
# Generating mask for folder Mar22bS1C4R3_DMl_200x_g.png
#
# image Mar20bS1C4R3_LHl_200x_g.png num 196
# here
# tensor(0.1581)
#
# Generating mask for folder Mar20bS1C4R3_LHl_200x_g.png
#
# image Mar27bS1C1R3_VLPAGr_200x_g.png num 197
# here
# tensor(0.1668)
#
# Generating mask for folder Mar27bS1C1R3_VLPAGr_200x_g.png
#
# image Mar21bS1C4R2_LHl_200x_g.png num 198
# here
# tensor(0.1266)
#
# Generating mask for folder Mar21bS1C4R2_LHl_200x_g.png
#
# image Mar20bS1C2R1_VLPAGr_200x_g.png num 199
# here
# tensor(0.1913)
#
# Generating mask for folder Mar20bS1C2R1_VLPAGr_200x_g.png
#
# image RT431S8C1R1_VLPAG_100x_g.png num 200
# here
# tensor(0.1039)
#
# Generating mask for folder RT431S8C1R1_VLPAG_100x_g.png
#
# image Mar22bS1C2R1_VLPAGl_200x_g.png num 201
# here
# tensor(0.1500)
#
# Generating mask for folder Mar22bS1C2R1_VLPAGl_200x_g.png
#
# image Mar23bS1C2R4_VLPAGl_200x_g.png num 202
# here
# tensor(0.1584)
#
# Generating mask for folder Mar23bS1C2R4_VLPAGl_200x_g.png
#
# image RT466S5C1R2_ParCortex_100x_g.png num 203
# here
# tensor(0.1242)
#
# Generating mask for folder RT466S5C1R2_ParCortex_100x_g.png
#
# no coord for  RT466S5C1R2_ParCortex_100x_g.png
# image Mar19bS1C5R2_LHr_200x_g.png num 204
# here
# tensor(0.1972)
#
# Generating mask for folder Mar19bS1C5R2_LHr_200x_g.png
#
# image Mar26bS1C4R2_LHr_200x_g.png num 205
# here
# tensor(0.1248)
#
# Generating mask for folder Mar26bS1C4R2_LHr_200x_g.png
#
# image Mar19bS1C4R2_DMl_200x_g.png num 206
# here
# tensor(0.2287)
#
# Generating mask for folder Mar19bS1C4R2_DMl_200x_g.png
#
# image Mar24bS1C2R1_LHl_200x_g.png num 207
# here
# tensor(0.1082)
#
# Generating mask for folder Mar24bS1C2R1_LHl_200x_g.png
#
# image Mar24bS1C3R2_LHr_200x_g.png num 208
# here
# tensor(0.1676)
#
# Generating mask for folder Mar24bS1C3R2_LHr_200x_g.png
#
# image Mar23bS1C5R2_LHr_200x_g.png num 209
# here
# tensor(0.1321)
#
# Generating mask for folder Mar23bS1C5R2_LHr_200x_g.png
#
# image Mar21bS2C2R2_DMr_200x_g.png num 210
# here
# tensor(0.1176)
#
# Generating mask for folder Mar21bS2C2R2_DMr_200x_g.png
#
# image Mar22bS1C3R1_DMl_200x_g.png num 211
# here
# tensor(0.1991)
#
# Generating mask for folder Mar22bS1C3R1_DMl_200x_g.png
#
# image Mar24bS1C2R3_LHr_200x_g.png num 212
# here
# tensor(0.1549)
#
# Generating mask for folder Mar24bS1C2R3_LHr_200x_g.png
#
# image Mar24bS2C1R3_VLPAGl_200x_g.png num 213
# here
# tensor(0.2531)
#
# Generating mask for folder Mar24bS2C1R3_VLPAGl_200x_g.png
#
# image Mar21bS1C1R2_VLPAGl_200x_g.png num 214
# here
# tensor(0.1021)
#
# Generating mask for folder Mar21bS1C1R2_VLPAGl_200x_g.png
#
# image Mar19bS1C5R2_DMr_200x_g.png num 215
# here
# tensor(0.2531)
#
# Generating mask for folder Mar19bS1C5R2_DMr_200x_g.png
#
# image Mar24bS1C1R2_LHl_200x_g.png num 216
# here
# tensor(0.1368)
#
# Generating mask for folder Mar24bS1C1R2_LHl_200x_g.png
#
# image Mar19bS1C5R1_DMl_200x_g.png num 217
# here
# tensor(0.1712)
#
# Generating mask for folder Mar19bS1C5R1_DMl_200x_g.png
#
# image Mar27bS1C2R3_LHr_200x_g.png num 218
# here
# tensor(0.1117)
#
# Generating mask for folder Mar27bS1C2R3_LHr_200x_g.png
#
# image Mar21bS1C4R2_LHr_200x_g.png num 219
# here
# tensor(0.1274)
#
# Generating mask for folder Mar21bS1C4R2_LHr_200x_g.png
#
# image Mar20bS1C2R2_VLPAGl_200x_g.png num 220
# here
# tensor(0.2437)
#
# Generating mask for folder Mar20bS1C2R2_VLPAGl_200x_g.png
#
# image Mar20bS2C1R3_DMl_200x_g.png num 221
# here
# tensor(0.1748)
#
# Generating mask for folder Mar20bS2C1R3_DMl_200x_g.png
#
# image Mar19bS1C4R3_DMl_200x_g.png num 222
# here
# tensor(0.2435)
#
# Generating mask for folder Mar19bS1C4R3_DMl_200x_g.png
#
# image Mar19bS2C2R1_LHl_200x_g.png num 223
# here
# tensor(0.1908)
#
# Generating mask for folder Mar19bS2C2R1_LHl_200x_g.png
#
# image Mar19bS1C2R3_VLPAGl_200x_g.png num 224
# here
# tensor(0.1866)
#
# Generating mask for folder Mar19bS1C2R3_VLPAGl_200x_g.png
#
# image RT463S4C3R2_VLPAG_100x_g.png num 225
# here
# tensor(0.1485)
#
# Generating mask for folder RT463S4C3R2_VLPAG_100x_g.png
#
# image Mar19bS2C1R2_LHl_200x_g.png num 226
# here
# tensor(0.1504)
#
# Generating mask for folder Mar19bS2C1R2_LHl_200x_g.png
#
# no coord for  Mar19bS2C1R2_LHl_200x_g.png
# image Mar23bS1C5R3_DMr_200x_g.png num 227
# here
# tensor(0.1696)
#
# Generating mask for folder Mar23bS1C5R3_DMr_200x_g.png
#
# image Mar19bS1C5R1_DMr_200x_g.png num 228
# here
# tensor(0.3114)
#
# Generating mask for folder Mar19bS1C5R1_DMr_200x_g.png
#
# image Mar26bS1C2R2_VLPAGl_200x_g.png num 229
# here
# tensor(0.2572)
#
# Generating mask for folder Mar26bS1C2R2_VLPAGl_200x_g.png
#
# image Mar24bS1C1R1_DMl_200x_g.png num 230
# here
# tensor(0.1418)
#
# Generating mask for folder Mar24bS1C1R1_DMl_200x_g.png
#
# image Mar22bS1C4R1_LHl_200x_g.png num 231
# here
# tensor(0.1806)
#
# Generating mask for folder Mar22bS1C4R1_LHl_200x_g.png
#
# image Mar27bS1C2R1_LHr_200x_g.png num 232
# here
# tensor(0.1049)
#
# Generating mask for folder Mar27bS1C2R1_LHr_200x_g.png
#
# image Mar22bS1C3R3_LHr_200x_g.png num 233
# here
# tensor(0.1166)
#
# Generating mask for folder Mar22bS1C3R3_LHr_200x_g.png
#
# image RT418S4C3R1_LH_100x_g.png num 234
# here
# tensor(0.1093)
#
# Generating mask for folder RT418S4C3R1_LH_100x_g.png
#
# image Mar23bS1C2R3_VLPAGr_200x_g.png num 235
# here
# tensor(0.1405)
#
# Generating mask for folder Mar23bS1C2R3_VLPAGr_200x_g.png
#
# image Mar22bS1C2R4_DMr_200x_g.png num 236
# here
# tensor(0.1885)
#
# Generating mask for folder Mar22bS1C2R4_DMr_200x_g.png
#
# image Mar26bS2C2R3_LHr_200x_g.png num 237
# here
# tensor(0.1480)
#
# Generating mask for folder Mar26bS2C2R3_LHr_200x_g.png
#
# image Mar19bS1C2R2_VLPAGl_200x_g.png num 238
# here
# tensor(0.1966)
#
# Generating mask for folder Mar19bS1C2R2_VLPAGl_200x_g.png
#
# image Mar21bS2C1R3_DMl_200x_g.png num 239
# here
# tensor(0.1009)
#
# Generating mask for folder Mar21bS2C1R3_DMl_200x_g.png
#
# image Mar21bS2C2R3_LHl_200x_g.png num 240
# here
# tensor(0.1734)
#
# Generating mask for folder Mar21bS2C2R3_LHl_200x_g.png
#
# image Mar22bS1C4R3_LHl_200x_g.png num 241
# here
# tensor(0.1457)
#
# Generating mask for folder Mar22bS1C4R3_LHl_200x_g.png
#
# image Mar21bS2C2R2_LHl_200x_g.png num 242
# here
# tensor(0.1077)
#
# Generating mask for folder Mar21bS2C2R2_LHl_200x_g.png
#
# image Mar23bS1C2R2_VLPAGr_200x_g.png num 243
# here
# tensor(0.1320)
#
# Generating mask for folder Mar23bS1C2R2_VLPAGr_200x_g.png
#
# image Mar21bS2C2R1_DMr_200x_g.png num 244
# here
# tensor(0.0847)
#
# Generating mask for folder Mar21bS2C2R1_DMr_200x_g.png
#
# image Mar21bS2C2R1_DMl_200x_g.png num 245
# here
# tensor(0.0888)
#
# Generating mask for folder Mar21bS2C2R1_DMl_200x_g.png
#
# image Mar26bS2C1R2_DMl_200x_g.png num 246
# here
# tensor(0.1258)
#
# Generating mask for folder Mar26bS2C1R2_DMl_200x_g.png
#
# image Mar24bS1C3R1_LHl_200x_g.png num 247
# here
# tensor(0.1703)
#
# Generating mask for folder Mar24bS1C3R1_LHl_200x_g.png
#
# image Mar21bS1C1R3_VLPAGl_200x_g.png num 248
# here
# tensor(0.1582)
#
# Generating mask for folder Mar21bS1C1R3_VLPAGl_200x_g.png
#
# image Mar21bS2C1R2_LHl_200x_g.png num 249
# here
# tensor(0.1190)
#
# Generating mask for folder Mar21bS2C1R2_LHl_200x_g.png
#
# image Mar19bS1C4R2_LHr_200x_g.png num 250
# here
# tensor(0.1911)
#
# Generating mask for folder Mar19bS1C4R2_LHr_200x_g.png
#
# image Mar26bS1C1R3_VLPAGr_200x_g.png num 251
# here
# tensor(0.1489)
#
# Generating mask for folder Mar26bS1C1R3_VLPAGr_200x_g.png
#
# image Mar27bS1C2R2_LHr_200x_g.png num 252
# here
# tensor(0.1041)
#
# Generating mask for folder Mar27bS1C2R2_LHr_200x_g.png
#
# image Mar23bS1C2R3_VLPAGl_200x_g.png num 253
# here
# tensor(0.1453)
#
# Generating mask for folder Mar23bS1C2R3_VLPAGl_200x_g.png
#
# image Mar24bS2C1R3_VLPAGr_200x_g.png num 254
# here
# tensor(0.2834)
#
# Generating mask for folder Mar24bS2C1R3_VLPAGr_200x_g.png

# %%
# model inference
for ix, f in enumerate(filenames):
    img = cv2.imread(str(train_val_images) + '/' +f)
    img = transform(img)
    img = torch.unsqueeze(img, 0)
    img = img.to(device).float()

    with torch.no_grad():
        print("image {} num {} ".format(f, ix))
        outputs = []
        for layer in conv_layers:
            img = layer(img)
            outputs.append(img)
            
        #processed = []
        for feature_map in outputs[selected]:
            
            feature_map = feature_map.squeeze(0)
            if len(feature_map.shape) < 3:
                gray_scale = feature_map
            else:
                gray_scale = torch.sum(feature_map,0)
                gray_scale = gray_scale / feature_map.shape[0]
            result = gray_scale.data.cpu().numpy()
            
    heat_map = (torch.from_numpy(result) - torch.from_numpy(result).min())\
                /(torch.from_numpy(result).max() - torch.from_numpy(result).min())
    
    histogram, bin_edges = np.histogram(heat_map, bins=100, range=(0, 1))
    peaks, _ = find_peaks(histogram, height=10000)
    med = torch.median(torch.flatten(heat_map))
    #print(med)
    
    if med > 0.5:
        heat_map = 1 - heat_map
        histogram, bin_edges = np.histogram(heat_map, bins=100, range=(0, 1))
        peaks, _ = find_peaks(histogram, height=10000)

        #th = med + 0.9*med
    try:
        th = (bin_edges[peaks][1]-bin_edges[peaks][0]) + bin_edges[peaks][1]
        preds_t = (heat_map > th)
    except:
        th = med + 0.9*med
        preds_t = (heat_map > th)
    

    # already circle images around dot annotation
    #mask = cv2.imread(str(train_val_masks) + '/' +f)
    #mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)[:, :, 0:1]
    
    mask = np.zeros((IMG_HEIGHT,IMG_WIDTH,3), np.uint8)
    mask.fill(0)
    print('\nGenerating mask for folder {}\n'.format(f))

    try:
        for index, r in labels_df.loc[f].iterrows():
            coords = r['dot']
            coords = [float(x.strip('(),')) for x in coords.split()]
            y, x = coords[0], coords[1]
            if 'RT' in f:
                cv2.circle(mask, (int(x), int(y)), RADIUS_RT, [255, 255, 255], -1)
            else:
                cv2.circle(mask, (int(x), int(y)), RADIUS, [255, 255, 255], -1)
    except:
        print('no coord for ',f)

    
    #mask_ws = create_mask(centers, f, radius=30, h=1200, w=1600)
    #mask_ws =  mask_ws.astype(bool)
    mask_ws = np.logical_and(np.squeeze(mask[:,:, 0]), preds_t)

    torch.cuda.empty_cache()
    
    
    plt.imsave(os.path.join(str(train_val_ws_masks), f.split('.')[0]+'.png'),
               mask_ws, cmap='gray')

# %%
plt.imshow(preds_t)

# %%
batch_size = 8
test_loader = DataLoader(cells_images, batch_size=batch_size)

# %%
x, y = next(iter(test_loader))

# %%
blocks = list(model.module.children()) #encoder, decoder, head

# %%
counter=0
# we will save the conv layer weights in this list
model_weights =[]
#we will save the 49 conv layers in this list
layers = []# get all the model children as list
for block in blocks:
    for n,p in list(block.named_modules()):
        if type(p) == nn.Conv2d:
            counter+=1
            model_weights.append(p.weight)
            layers.append(p)

# %%
for ix, l in enumerate(layers):
    print(ix, l)
# Out:
# 0 Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1))
# 1 Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2 Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 3 Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 4 Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 5 Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
# 6 Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 7 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 8 Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
# 9 Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
# 10 Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
# 11 Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
# 12 Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
# 13 Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
# 14 Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 15 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 16 Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 17 Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 18 Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 19 Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 20 Conv2d(16, 3, kernel_size=(1, 1), stride=(1, 1))

# %%
remove = [5,8,11]

# %%
conv_layers = []
remove = [5,8,11]
for i, l in enumerate(layers):
    if i not in remove:
        conv_layers.append(l)

# %%
image = x[3].unsqueeze(0).to(device)

# %%
#conv_layers = conv_layers[0:4]

# %%
conv_layers
# Out:
# [Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1)),
#  Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2)),
#  Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2)),
#  Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2)),
#  Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2)),
#  Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#  Conv2d(16, 3, kernel_size=(1, 1), stride=(1, 1))]

# %%
outputs = []
names = []
for layer in conv_layers[0:]:
    image = layer(image)
    outputs.append(image)
    names.append(str(layer))
print(len(outputs))#print feature_maps
for feature_map in outputs:
    print(feature_map.shape)
# Out:
# 18
# torch.Size([1, 1, 1200, 1600])
# torch.Size([1, 16, 1200, 1600])
# torch.Size([1, 16, 1200, 1600])
# torch.Size([1, 32, 1200, 1600])
# torch.Size([1, 32, 1200, 1600])
# torch.Size([1, 64, 1200, 1600])
# torch.Size([1, 64, 1200, 1600])
# torch.Size([1, 128, 1200, 1600])
# torch.Size([1, 128, 1200, 1600])
# torch.Size([1, 128, 1200, 1600])
# torch.Size([1, 128, 1200, 1600])
# torch.Size([1, 64, 1200, 1600])
# torch.Size([1, 64, 1200, 1600])
# torch.Size([1, 32, 1200, 1600])
# torch.Size([1, 32, 1200, 1600])
# torch.Size([1, 16, 1200, 1600])
# torch.Size([1, 16, 1200, 1600])
# torch.Size([1, 3, 1200, 1600])

# %%
processed = []
for feature_map in outputs:
    feature_map = feature_map.squeeze(0)
    gray_scale = torch.sum(feature_map,0)
    gray_scale = gray_scale / feature_map.shape[0]
    processed.append(gray_scale.data.cpu().numpy())
    
    
for fm in processed:
    print(fm.shape)
# Out:
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)

# %%
fig = plt.figure(figsize=(30, 50))
for i in range(len(processed)):
    print(processed[i].shape)
    a = fig.add_subplot(5, 4, i+1)
    imgplot = plt.imshow(processed[i])
    a.axis("off")
    a.set_title(names[i].split('(')[0], fontsize=30)
plt.savefig(str('feature_maps.jpg'), bbox_inches='tight')
# Out:
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)
# (1200, 1600)

# %%
from scipy.signal import find_peaks

# %%
max_diff = 0
diff = 0
selected=0
for ix, p in enumerate(processed):
    pv = (p -p.min())\
        /(p.max() - p.min())
    histogram, bin_edges = np.histogram(pv, bins=100, range=(0, 1))
    peaks, _ = find_peaks(histogram, height=10000)
    
    plt.figure()
    plt.title("Grayscale Histogram")
    plt.xlabel("grayscale value")
    plt.ylabel("pixel count")
    plt.xlim([0.0, 1.0]) 
    if len(peaks) > 1:
        plt.axvline(bin_edges[peaks][0])
        plt.axvline(bin_edges[peaks][1])
        plt.xlim([0, bin_edges[peaks][1]*2])
        plt.title('fm {} with difference {}'.format(ix, bin_edges[peaks][1]-bin_edges[peaks][0]))
        print(bin_edges[peaks][1]-bin_edges[peaks][0], ix)
        diff = bin_edges[peaks][1]-bin_edges[peaks][0]
        
    else:
        plt.axvline(bin_edges[peaks][0])
        plt.xlim([0, bin_edges[peaks][0]*2])
        print("only one peak")
        plt.title("fm {} with only one peak".format(ix))
        
    if diff > max_diff:
        max_diff = diff
        selected = ix
        
    plt.plot(bin_edges[0:-1], histogram)
# Out:
# only one peak
# 0.049999982 1
# 0.049999982 2
# 0.050000012 3
# 0.050000012 4
# only one peak
# 0.04000002 6
# 0.050000012 7
# 0.050000012 8
# 0.060000002 9
# 0.059999973 10
# only one peak
# 0.04000002 12
# 0.060000002 13
# 0.050000012 14
# only one peak
# 0.050000012 16
# 0.050000012 17

# %%
plt.imshow(processed[selected])

# %%
fm = processed[selected]

# %%
#heat_map_a = torch.nn.Sigmoid()(torch.from_numpy(fm))
heat_map_a = (torch.from_numpy(fm) - torch.from_numpy(fm).min())\
/(torch.from_numpy(fm).max() - torch.from_numpy(fm).min())

# %%
histogram, bin_edges = np.histogram(heat_map_a, bins=100, range=(0, 1))
peaks, _ = find_peaks(histogram, height=10000)

# %%
heat_map = torch.from_numpy(fm)

# %%
med = torch.median(torch.flatten(heat_map_a))
if med > 0.5:
    heat_map_a = 1 - heat_map_a
    histogram, bin_edges = np.histogram(heat_map_a, bins=100, range=(0, 1))
    peaks, _ = find_peaks(histogram, height=10000)
print(med)

#th = med + 0.9*med
th = (bin_edges[peaks][1]-bin_edges[peaks][0]) + bin_edges[peaks][1]
heat_map_a = (heat_map_a > th)
# Out:
# tensor(0.4038)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

im = axes[0].pcolormesh(np.flipud(heat_map_a.cpu().detach().squeeze()), cmap='jet')
divider = make_axes_locatable(axes[0])
cax = divider.append_axes("right", size="5%", pad=0.05)
plt.colorbar(im, cax=cax)
axes[0].set_title('Predicted heatmap') 

im = axes[1].pcolormesh(np.flipud(heat_map.cpu().detach().squeeze()), cmap='jet')
divider = make_axes_locatable(axes[1])
cax = divider.append_axes("right", size="5%", pad=0.05)
plt.colorbar(im, cax=cax)
axes[1].set_title('Predicted heatmap')
# Out:
# Text(0.5, 1.0, 'Predicted heatmap')

# %%
torch.median(torch.flatten(heat_map_a))

heat_map_a = 1- heat_map_a
# Out:
# tensor(0.2161)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

im = axes[0].pcolormesh(np.flipud(heat_map_a.cpu().detach().squeeze()), cmap='jet')
divider = make_axes_locatable(axes[0])
cax = divider.append_axes("right", size="5%", pad=0.05)
plt.colorbar(im, cax=cax)
axes[0].set_title('Predicted heatmap') 

im = axes[1].pcolormesh(np.flipud(heat_map.cpu().detach().squeeze()), cmap='jet')
divider = make_axes_locatable(axes[1])
cax = divider.append_axes("right", size="5%", pad=0.05)
plt.colorbar(im, cax=cax)
axes[1].set_title('Predicted heatmap')
# Out:
# Text(0.5, 1.0, 'Predicted heatmap')

# %%
nn.

# %%
plt.imshow(x[0].permute(1,2,0))

# %%
for name, module in model.named_modules():
    print(name)
# Out:
# module
# module.encoder
# module.encoder.colorspace
# module.encoder.conv_block
# module.encoder.conv_block.conv_block
# module.encoder.conv_block.conv_block.batchnorm2d_0
# module.encoder.conv_block.conv_block.activation_1
# module.encoder.conv_block.conv_block.conv2d_2
# module.encoder.conv_block.conv_block.batchnorm2d_3
# module.encoder.conv_block.conv_block.activation_4
# module.encoder.conv_block.conv_block.conv2d_5
# module.encoder.pool1
# module.encoder.residual_block1
# module.encoder.residual_block1.conv_path
# module.encoder.residual_block1.conv_path.conv_block
# module.encoder.residual_block1.conv_path.conv_block.batchnorm2d_0
# module.encoder.residual_block1.conv_path.conv_block.activation_1
# module.encoder.residual_block1.conv_path.conv_block.conv2d_2
# module.encoder.residual_block1.conv_path.conv_block.batchnorm2d_3
# module.encoder.residual_block1.conv_path.conv_block.activation_4
# module.encoder.residual_block1.conv_path.conv_block.conv2d_5
# module.encoder.residual_block1.id_path
# module.encoder.residual_block1.id_path.conv2d_1
# module.encoder.residual_block1.add
# module.encoder.pool2
# module.encoder.residual_block2
# module.encoder.residual_block2.conv_path
# module.encoder.residual_block2.conv_path.conv_block
# module.encoder.residual_block2.conv_path.conv_block.batchnorm2d_0
# module.encoder.residual_block2.conv_path.conv_block.activation_1
# module.encoder.residual_block2.conv_path.conv_block.conv2d_2
# module.encoder.residual_block2.conv_path.conv_block.batchnorm2d_3
# module.encoder.residual_block2.conv_path.conv_block.activation_4
# module.encoder.residual_block2.conv_path.conv_block.conv2d_5
# module.encoder.residual_block2.id_path
# module.encoder.residual_block2.id_path.conv2d_1
# module.encoder.residual_block2.add
# module.encoder.pool3
# module.encoder.bottleneck
# module.encoder.bottleneck.residual_block1
# module.encoder.bottleneck.residual_block1.conv_path
# module.encoder.bottleneck.residual_block1.conv_path.conv_block
# module.encoder.bottleneck.residual_block1.conv_path.conv_block.batchnorm2d_0
# module.encoder.bottleneck.residual_block1.conv_path.conv_block.activation_1
# module.encoder.bottleneck.residual_block1.conv_path.conv_block.conv2d_2
# module.encoder.bottleneck.residual_block1.conv_path.conv_block.batchnorm2d_3
# module.encoder.bottleneck.residual_block1.conv_path.conv_block.activation_4
# module.encoder.bottleneck.residual_block1.conv_path.conv_block.conv2d_5
# module.encoder.bottleneck.residual_block1.id_path
# module.encoder.bottleneck.residual_block1.id_path.conv2d_1
# module.encoder.bottleneck.residual_block1.add
# module.encoder.bottleneck.residual_block2
# module.encoder.bottleneck.residual_block2.conv_path
# module.encoder.bottleneck.residual_block2.conv_path.conv_block
# module.encoder.bottleneck.residual_block2.conv_path.conv_block.batchnorm2d_0
# module.encoder.bottleneck.residual_block2.conv_path.conv_block.activation_1
# module.encoder.bottleneck.residual_block2.conv_path.conv_block.conv2d_2
# module.encoder.bottleneck.residual_block2.conv_path.conv_block.batchnorm2d_3
# module.encoder.bottleneck.residual_block2.conv_path.conv_block.activation_4
# module.encoder.bottleneck.residual_block2.conv_path.conv_block.conv2d_5
# module.encoder.bottleneck.residual_block2.id_path
# module.encoder.bottleneck.residual_block2.id_path.identity
# module.encoder.bottleneck.residual_block2.add
# module.decoder
# module.decoder.upconv_block1
# module.decoder.upconv_block1.id_path
# module.decoder.upconv_block1.id_path.up_conv
# module.decoder.upconv_block1.id_path.concat
# module.decoder.upconv_block1.conv_path
# module.decoder.upconv_block1.conv_path.conv_block
# module.decoder.upconv_block1.conv_path.conv_block.batchnorm2d_0
# module.decoder.upconv_block1.conv_path.conv_block.activation_1
# module.decoder.upconv_block1.conv_path.conv_block.conv2d_2
# module.decoder.upconv_block1.conv_path.conv_block.batchnorm2d_3
# module.decoder.upconv_block1.conv_path.conv_block.activation_4
# module.decoder.upconv_block1.conv_path.conv_block.conv2d_5
# module.decoder.upconv_block1.add
# module.decoder.upconv_block2
# module.decoder.upconv_block2.id_path
# module.decoder.upconv_block2.id_path.up_conv
# module.decoder.upconv_block2.id_path.concat
# module.decoder.upconv_block2.conv_path
# module.decoder.upconv_block2.conv_path.conv_block
# module.decoder.upconv_block2.conv_path.conv_block.batchnorm2d_0
# module.decoder.upconv_block2.conv_path.conv_block.activation_1
# module.decoder.upconv_block2.conv_path.conv_block.conv2d_2
# module.decoder.upconv_block2.conv_path.conv_block.batchnorm2d_3
# module.decoder.upconv_block2.conv_path.conv_block.activation_4
# module.decoder.upconv_block2.conv_path.conv_block.conv2d_5
# module.decoder.upconv_block2.add
# module.decoder.upconv_block3
# module.decoder.upconv_block3.id_path
# module.decoder.upconv_block3.id_path.up_conv
# module.decoder.upconv_block3.id_path.concat
# module.decoder.upconv_block3.conv_path
# module.decoder.upconv_block3.conv_path.conv_block
# module.decoder.upconv_block3.conv_path.conv_block.batchnorm2d_0
# module.decoder.upconv_block3.conv_path.conv_block.activation_1
# module.decoder.upconv_block3.conv_path.conv_block.conv2d_2
# module.decoder.upconv_block3.conv_path.conv_block.batchnorm2d_3
# module.decoder.upconv_block3.conv_path.conv_block.activation_4
# module.decoder.upconv_block3.conv_path.conv_block.conv2d_5
# module.decoder.upconv_block3.add
# module.head
# module.head.conv2d
# module.head.act

# %%
activation = {}
def getActivation(name):
  # the hook signature
  def hook(model, input, output):
    activation[name] = output.detach()
    return hook

# %%
model.module.encoder.colorspace.register_forward_hook(getActivation('module.encoder.colorspace'))

# %%
blocks = list(list(model.children())[0].children())

# %%
list(b.children())
# Out:
# [Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1)),
#  ConvBlock(
#    (conv_block): ModuleDict(
#      (batchnorm2d_0): BatchNorm2d(1, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#      (activation_1): ELU(alpha=1.0)
#      (conv2d_2): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (batchnorm2d_3): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#      (activation_4): ELU(alpha=1.0)
#      (conv2d_5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#    )
#  ),
#  MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
#  ResidualBlock(
#    (conv_path): ConvBlock(
#      (conv_block): ModuleDict(
#        (batchnorm2d_0): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#        (activation_1): ELU(alpha=1.0)
#        (conv2d_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (batchnorm2d_3): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#        (activation_4): ELU(alpha=1.0)
#        (conv2d_5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#    )
#    (id_path): IdentityPath(
#      (conv2d_1): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#    )
#    (add): Add()
#  ),
#  MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
#  ResidualBlock(
#    (conv_path): ConvBlock(
#      (conv_block): ModuleDict(
#        (batchnorm2d_0): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#        (activation_1): ELU(alpha=1.0)
#        (conv2d_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (batchnorm2d_3): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#        (activation_4): ELU(alpha=1.0)
#        (conv2d_5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#    )
#    (id_path): IdentityPath(
#      (conv2d_1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#    )
#    (add): Add()
#  ),
#  MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
#  Bottleneck(
#    (residual_block1): ResidualBlock(
#      (conv_path): ConvBlock(
#        (conv_block): ModuleDict(
#          (batchnorm2d_0): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_1): ELU(alpha=1.0)
#          (conv2d_2): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#          (batchnorm2d_3): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_4): ELU(alpha=1.0)
#          (conv2d_5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#        )
#      )
#      (id_path): IdentityPath(
#        (conv2d_1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (add): Add()
#    )
#    (residual_block2): ResidualBlock(
#      (conv_path): ConvBlock(
#        (conv_block): ModuleDict(
#          (batchnorm2d_0): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_1): ELU(alpha=1.0)
#          (conv2d_2): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#          (batchnorm2d_3): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_4): ELU(alpha=1.0)
#          (conv2d_5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#        )
#      )
#      (id_path): IdentityPath(
#        (identity): Identity()
#      )
#      (add): Add()
#    )
#  )]

# %%
counter = 0

# %%
for b in blocks:
    print('this is a block')
    model_children = list(b.children())
    for i in range(len(model_children)):
        print(model_children[i])
        model_childrens = list(model_children[i].children())
        for i in range(len(model_childrens)):
            print(model_childrens[i])
            if type(model_childrens[i]) == nn.Conv2d:
                counter+=1
# Out:
# this is a block
# Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1))
# ConvBlock(
#   (conv_block): ModuleDict(
#     (batchnorm2d_0): BatchNorm2d(1, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_1): ELU(alpha=1.0)
#     (conv2d_2): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm2d_3): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_4): ELU(alpha=1.0)
#     (conv2d_5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# ModuleDict(
#   (batchnorm2d_0): BatchNorm2d(1, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#   (activation_1): ELU(alpha=1.0)
#   (conv2d_2): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm2d_3): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#   (activation_4): ELU(alpha=1.0)
#   (conv2d_5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ResidualBlock(
#   (conv_path): ConvBlock(
#     (conv_block): ModuleDict(
#       (batchnorm2d_0): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_1): ELU(alpha=1.0)
#       (conv2d_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batchnorm2d_3): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_4): ELU(alpha=1.0)
#       (conv2d_5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (id_path): IdentityPath(
#     (conv2d_1): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (add): Add()
# )
# ConvBlock(
#   (conv_block): ModuleDict(
#     (batchnorm2d_0): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_1): ELU(alpha=1.0)
#     (conv2d_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm2d_3): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_4): ELU(alpha=1.0)
#     (conv2d_5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# IdentityPath(
#   (conv2d_1): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
# )
# Add()
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ResidualBlock(
#   (conv_path): ConvBlock(
#     (conv_block): ModuleDict(
#       (batchnorm2d_0): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_1): ELU(alpha=1.0)
#       (conv2d_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batchnorm2d_3): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_4): ELU(alpha=1.0)
#       (conv2d_5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (id_path): IdentityPath(
#     (conv2d_1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (add): Add()
# )
# ConvBlock(
#   (conv_block): ModuleDict(
#     (batchnorm2d_0): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_1): ELU(alpha=1.0)
#     (conv2d_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm2d_3): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_4): ELU(alpha=1.0)
#     (conv2d_5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# IdentityPath(
#   (conv2d_1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
# )
# Add()
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# Bottleneck(
#   (residual_block1): ResidualBlock(
#     (conv_path): ConvBlock(
#       (conv_block): ModuleDict(
#         (batchnorm2d_0): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (activation_1): ELU(alpha=1.0)
#         (conv2d_2): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm2d_3): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (activation_4): ELU(alpha=1.0)
#         (conv2d_5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       )
#     )
#     (id_path): IdentityPath(
#       (conv2d_1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (add): Add()
#   )
#   (residual_block2): ResidualBlock(
#     (conv_path): ConvBlock(
#       (conv_block): ModuleDict(
#         (batchnorm2d_0): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (activation_1): ELU(alpha=1.0)
#         (conv2d_2): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm2d_3): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (activation_4): ELU(alpha=1.0)
#         (conv2d_5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       )
#     )
#     (id_path): IdentityPath(
#       (identity): Identity()
#     )
#     (add): Add()
#   )
# )
# ResidualBlock(
#   (conv_path): ConvBlock(
#     (conv_block): ModuleDict(
#       (batchnorm2d_0): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_1): ELU(alpha=1.0)
#       (conv2d_2): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (batchnorm2d_3): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_4): ELU(alpha=1.0)
#       (conv2d_5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
#   (id_path): IdentityPath(
#     (conv2d_1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (add): Add()
# )
# ResidualBlock(
#   (conv_path): ConvBlock(
#     (conv_block): ModuleDict(
#       (batchnorm2d_0): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_1): ELU(alpha=1.0)
#       (conv2d_2): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (batchnorm2d_3): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_4): ELU(alpha=1.0)
#       (conv2d_5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
#   (id_path): IdentityPath(
#     (identity): Identity()
#   )
#   (add): Add()
# )
# this is a block
# UpResidualBlock(
#   (id_path): ModuleDict(
#     (up_conv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (concat): Concatenate()
#   )
#   (conv_path): ConvBlock(
#     (conv_block): ModuleDict(
#       (batchnorm2d_0): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_1): ELU(alpha=1.0)
#       (conv2d_2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batchnorm2d_3): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_4): ELU(alpha=1.0)
#       (conv2d_5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (add): Add()
# )
# ModuleDict(
#   (up_conv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (concat): Concatenate()
# )
# ConvBlock(
#   (conv_block): ModuleDict(
#     (batchnorm2d_0): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_1): ELU(alpha=1.0)
#     (conv2d_2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm2d_3): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_4): ELU(alpha=1.0)
#     (conv2d_5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# Add()
# UpResidualBlock(
#   (id_path): ModuleDict(
#     (up_conv): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (concat): Concatenate()
#   )
#   (conv_path): ConvBlock(
#     (conv_block): ModuleDict(
#       (batchnorm2d_0): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_1): ELU(alpha=1.0)
#       (conv2d_2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batchnorm2d_3): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_4): ELU(alpha=1.0)
#       (conv2d_5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (add): Add()
# )
# ModuleDict(
#   (up_conv): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (concat): Concatenate()
# )
# ConvBlock(
#   (conv_block): ModuleDict(
#     (batchnorm2d_0): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_1): ELU(alpha=1.0)
#     (conv2d_2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm2d_3): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_4): ELU(alpha=1.0)
#     (conv2d_5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# Add()
# UpResidualBlock(
#   (id_path): ModuleDict(
#     (up_conv): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#     (concat): Concatenate()
#   )
#   (conv_path): ConvBlock(
#     (conv_block): ModuleDict(
#       (batchnorm2d_0): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_1): ELU(alpha=1.0)
#       (conv2d_2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batchnorm2d_3): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (activation_4): ELU(alpha=1.0)
#       (conv2d_5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (add): Add()
# )
# ModuleDict(
#   (up_conv): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#   (concat): Concatenate()
# )
# ConvBlock(
#   (conv_block): ModuleDict(
#     (batchnorm2d_0): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_1): ELU(alpha=1.0)
#     (conv2d_2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm2d_3): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (activation_4): ELU(alpha=1.0)
#     (conv2d_5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# Add()
# this is a block
# Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
# Sigmoid()

# %%
# we will save the conv layer weights in this list
model_weights =[]
#we will save the 49 conv layers in this list
conv_layers = []# get all the model children as list
blocks = list(list(model.children())[0].children())#counter to keep count of the conv layers
counter = 0#append all the conv layers and their respective wights to the list
for i in range(len(model_children)):
    if type(model_children[i]) == nn.Conv2d:
        counter+=1
        model_weights.append(model_children[i].weight)
        conv_layers.append(model_children[i])
    elif type(model_children[i]) == nn.Sequential:
        for j in range(len(model_children[i])):
            for child in model_children[i][j].children():
                if type(child) == nn.Conv2d:
                    counter+=1
                    model_weights.append(child.weight)
                    conv_layers.append(child)
print(f"Total convolution layers: {counter}")
print("conv_layers")

# %%
# we will save the conv layer weights in this list
model_weights =[]
#we will save the 49 conv layers in this list
conv_layers = []# get all the model children as list
model_children = list(model.children())#counter to keep count of the conv layers
counter = 0#append all the conv layers and their respective wights to the list
for i in range(len(model_children)):
    if type(model_children[i]) == nn.Conv2d:
        counter+=1
        model_weights.append(model_children[i].weight)
        conv_layers.append(model_children[i])
    elif type(model_children[i]) == nn.Sequential:
        for j in range(len(model_children[i])):
            for child in model_children[i][j].children():
                if type(child) == nn.Conv2d:
                    counter+=1
                    model_weights.append(child.weight)
                    conv_layers.append(child)
print(f"Total convolution layers: {counter}")
print("conv_layers")
# Out:
# Total convolution layers: 0
# conv_layers

# %%
model.eval()
with torch.no_grad():
    heatmap = model(x.to(device))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_15603/3174340817.py in <module>
#       1 model.eval()
#       2 with torch.no_grad():
# ----> 3     heatmap = model(x.to(device))
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     164
#     165             if len(self.device_ids) == 1:
# --> 166                 return self.module(*inputs[0], **kwargs[0])
#     167             replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     168             outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Documents/backup_rob/P.h.D/cells/cell_counting_torch/model/resunet.py in forward(self, x)
#      85
#      86     def forward(self, x: Tensor) -> Tensor:
# ---> 87         return self._forward_impl(x)
#      88
#      89
#
# ~/Documents/backup_rob/P.h.D/cells/cell_counting_torch/model/resunet.py in _forward_impl(self, x)
#      73         for layer, long_connect in zip(self.decoder.values(), reversed(downblocks)):
#      74             x = layer(x, long_connect)
# ---> 75         return self.head(x)
#      76
#      77     def init_kaiming_normal(self, mode='fan_in'):
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Documents/backup_rob/P.h.D/cells/cell_counting_torch/model/_blocks.py in forward(self, x)
#     148
#     149     def forward(self, x):
# --> 150         return self.act(self.conv2d(x))
#     151
#     152 class HeatmapAE(nn.Module):
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1129         if _global_forward_hooks or self._forward_hooks:
#    1130             for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
# -> 1131                 hook_result = hook(self, input, result)
#    1132                 if hook_result is not None:
#    1133                     result = hook_result
#
# TypeError: 'NoneType' object is not callable

# %%
print(activation)

# detach the hooks
h1.remove()
# Out:
# {}

# %%
model.eval()
with torch.no_grad():
    heatmap = model(x.to(device))
    #heatmap = 1 - heatmap
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_15603/269752250.py in <module>
#       1 model.eval()
#       2 with torch.no_grad():
# ----> 3     heatmap = model(x.to(device))
#       4     #heatmap = 1 - heatmap
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     164
#     165             if len(self.device_ids) == 1:
# --> 166                 return self.module(*inputs[0], **kwargs[0])
#     167             replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     168             outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Documents/backup_rob/P.h.D/cells/cell_counting_torch/model/resunet.py in forward(self, x)
#      85
#      86     def forward(self, x: Tensor) -> Tensor:
# ---> 87         return self._forward_impl(x)
#      88
#      89
#
# ~/Documents/backup_rob/P.h.D/cells/cell_counting_torch/model/resunet.py in _forward_impl(self, x)
#      68         downblocks = []
#      69         for lbl, layer in self.encoder.items():
# ---> 70             x = layer(x)
#      71             if 'block' in lbl: downblocks.append(x)
#      72             # NEXT loop is hon the values and so we don't hane the name as in the items of the previous loop
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1129         if _global_forward_hooks or self._forward_hooks:
#    1130             for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
# -> 1131                 hook_result = hook(self, input, result)
#    1132                 if hook_result is not None:
#    1133                     result = hook_result
#
# TypeError: 'NoneType' object is not callable

# %%
heatmap.shape
# Out:
# torch.Size([8, 1, 1200, 1600])

# %%
save = False

# %%
for i in range(heatmap.size()[0]):
    
#     print(test_ids[i+start])
    original = x[i].permute(1,2,0)
    target = y[i].permute(1,2,0)
    heat_map = heatmap[i]

    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
       
    im = axes[0].imshow(original)
    axes[0].set_title('Original')

    im = axes[1].imshow(np.squeeze(target), cmap='gray')
    axes[1].set_title('Target')

    im = axes[2].pcolormesh(np.flipud(heat_map.cpu().detach().squeeze()), cmap='jet')
    divider = make_axes_locatable(axes[2])
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    axes[2].set_title('Predicted heatmap') 
    
    if save:
        if os.path.exists('../figure_results/{}/{}'.format(model_name.split('.')[0], dataset)):
            print('path alredy exixts')
        else:
            os.makedirs('../figure_results/{}/{}'.format(model_name.split('.')[0], dataset))
        
        plt.savefig('../figure_results/{}/{}/{}_{}.png'.format(model_name.split('.')[0], \
                                                               dataset, model_name.split('.')[0],i))

# %%
list(list(model.children())[0].children())
# Out:
# [ModuleDict(
#    (colorspace): Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1))
#    (conv_block): ConvBlock(
#      (conv_block): ModuleDict(
#        (batchnorm2d_0): BatchNorm2d(1, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#        (activation_1): ELU(alpha=1.0)
#        (conv2d_2): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (batchnorm2d_3): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#        (activation_4): ELU(alpha=1.0)
#        (conv2d_5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#    )
#    (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#    (residual_block1): ResidualBlock(
#      (conv_path): ConvBlock(
#        (conv_block): ModuleDict(
#          (batchnorm2d_0): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_1): ELU(alpha=1.0)
#          (conv2d_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#          (batchnorm2d_3): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_4): ELU(alpha=1.0)
#          (conv2d_5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        )
#      )
#      (id_path): IdentityPath(
#        (conv2d_1): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (add): Add()
#    )
#    (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#    (residual_block2): ResidualBlock(
#      (conv_path): ConvBlock(
#        (conv_block): ModuleDict(
#          (batchnorm2d_0): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_1): ELU(alpha=1.0)
#          (conv2d_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#          (batchnorm2d_3): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_4): ELU(alpha=1.0)
#          (conv2d_5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        )
#      )
#      (id_path): IdentityPath(
#        (conv2d_1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (add): Add()
#    )
#    (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#    (bottleneck): Bottleneck(
#      (residual_block1): ResidualBlock(
#        (conv_path): ConvBlock(
#          (conv_block): ModuleDict(
#            (batchnorm2d_0): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#            (activation_1): ELU(alpha=1.0)
#            (conv2d_2): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#            (batchnorm2d_3): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#            (activation_4): ELU(alpha=1.0)
#            (conv2d_5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#          )
#        )
#        (id_path): IdentityPath(
#          (conv2d_1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#        )
#        (add): Add()
#      )
#      (residual_block2): ResidualBlock(
#        (conv_path): ConvBlock(
#          (conv_block): ModuleDict(
#            (batchnorm2d_0): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#            (activation_1): ELU(alpha=1.0)
#            (conv2d_2): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#            (batchnorm2d_3): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#            (activation_4): ELU(alpha=1.0)
#            (conv2d_5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#          )
#        )
#        (id_path): IdentityPath(
#          (identity): Identity()
#        )
#        (add): Add()
#      )
#    )
#  ),
#  ModuleDict(
#    (upconv_block1): UpResidualBlock(
#      (id_path): ModuleDict(
#        (up_conv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#        (concat): Concatenate()
#      )
#      (conv_path): ConvBlock(
#        (conv_block): ModuleDict(
#          (batchnorm2d_0): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_1): ELU(alpha=1.0)
#          (conv2d_2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#          (batchnorm2d_3): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_4): ELU(alpha=1.0)
#          (conv2d_5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        )
#      )
#      (add): Add()
#    )
#    (upconv_block2): UpResidualBlock(
#      (id_path): ModuleDict(
#        (up_conv): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#        (concat): Concatenate()
#      )
#      (conv_path): ConvBlock(
#        (conv_block): ModuleDict(
#          (batchnorm2d_0): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_1): ELU(alpha=1.0)
#          (conv2d_2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#          (batchnorm2d_3): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_4): ELU(alpha=1.0)
#          (conv2d_5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        )
#      )
#      (add): Add()
#    )
#    (upconv_block3): UpResidualBlock(
#      (id_path): ModuleDict(
#        (up_conv): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#        (concat): Concatenate()
#      )
#      (conv_path): ConvBlock(
#        (conv_block): ModuleDict(
#          (batchnorm2d_0): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_1): ELU(alpha=1.0)
#          (conv2d_2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#          (batchnorm2d_3): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#          (activation_4): ELU(alpha=1.0)
#          (conv2d_5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        )
#      )
#      (add): Add()
#    )
#  ),
#  Heatmap(
#    (conv2d): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#    (act): Sigmoid()
#  )]

# %%
counter=0
# we will save the conv layer weights in this list
model_weights =[]
#we will save the 49 conv layers in this list
conv_layers = []# get all the model children as list
for block in blocks:
    for c in list(block.children()):
        if type(c) == nn.Conv2d:
            counter+=1
            model_weights.append(c.weight)
            conv_layers.append(c)
        else:
            for cc in list(c.children()):
                if type(cc) == nn.Conv2d:
                    counter+=1
                    model_weights.append(cc.weight)
                    conv_layers.append(cc)
                else:
                    for ccc in list(cc.children()):
                        if type(ccc) == nn.Conv2d:
                            counter+=1
                            model_weights.append(ccc.weight)
                            conv_layers.append(ccc)
                        else:
                            for cccc in list(ccc.children()):
                                if type(cccc) == nn.Conv2d:
                                    counter+=1
                                    model_weights.append(cccc.weight)
                                    conv_layers.append(cccc)
                                else:
                                    for ccccc in list(cccc.children()):
                                        if type(ccccc) == nn.Conv2d:
                                            counter+=1
                                            model_weights.append(ccccc.weight)
                                            conv_layers.append(ccccc)

# %%
 model.module.encoder.colorspace
# Out:
# Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1))

# %%
activation = {}
def getActivation(name):
  # the hook signature
  def hook(model, input, output):
    activation[name] = output.detach()
    return hook

model.module.encoder.colorspace

# register forward hooks on the layers of choice
#h1 = model.module.encoder.colorspace.register_forward_hook(getActivation('Conv2d'))
#h2 = model.maxpool.register_forward_hook(getActivation('maxpool'))
#h3 = model.layer3[0].downsample[1].register_forward_hook(getActivation('comp'))

# %%
from types import MethodType

def _forward_impl_my(self, x):
    downblocks = []
    for lbl, layer in self.encoder.items():
        x = layer(x)
        if 'block' in lbl: downblocks.append(x)
        # NEXT loop is hon the values and so we don't hane the name as in the items of the previous loop
    for layer, long_connect in zip(self.decoder.values(), reversed(downblocks)):
        x = layer(x, long_connect)
    return self.head(x)

model._forward_impl = MethodType(_forward_impl_my, model)
